# %%
import pandas as pd
from collections import Counter
#import collections

# %%
colnames = ["text"]
df = pd.read_csv("sah_wikipedia_2021_100K.txt", sep="\t", encoding="utf-8", header=None, names=colnames)
df.head()
# Out:
#                                                 text
# 0  10 сыл диэн хоһооннорун уонна поэмаларын хомуу...
# 1  ¹ 1939 уонна 1959 сыллааҕы биэрэпискэ Саккырыы...
# 2  ¨1929 сыллаахха сэтинньигэ ороболууссуйэни ута...
# 3  ¨1930 сыллаахха муус устарга тройка суутунан 3...
# 4  «1941-1945 с.с. Аҕа дойду сэриитигэр үлэҕэ кил...

# %%
#df = df.drop("index", axis=1)

# %%
df["text"] = df["text"].str.replace("[^\w\s]", " ", regex=True)

# %%
df["text"] = df["text"].str.replace("  ", " ")

# %%
df["text"] = df["text"].str.lower()

# %%
df["text"] = df["text"].str.replace("\n", "")

# %%
df["text"] = df["text"].str.replace("\d*", "", regex=True)

# %%
wiki_texts = " ".join(df["text"])

# %%
dct = Counter(wiki_texts.split(" "))

# %% [markdown]
# ## Removing non yakut words in corpus

# %%
sahalpha = ["ҥ", "ҕ", "ө", "һ", "ү"]

# %%
a = ord('а')

# %%
rus = "".join([chr(i) for i in range(a, a + 6)] + [chr(a + 33)] + [chr(i) for i in range(a + 6, a + 32)])
rus
# Out:
# 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'

# %%
for i in rus:
    sahalpha.append(i)
sahalpha[0:10]
# Out:
# ['ҥ', 'ҕ', 'ө', 'һ', 'ү', 'а', 'б', 'в', 'г', 'д']

# %%
new_dct = {key:val for key, val in dct.items() if key.startswith(tuple(sahalpha))}
new_dct
# Out:
# {'сыл': 2643,
#  'диэн': 16757,
#  'хоһооннорун': 95,
#  'уонна': 16435,
#  'поэмаларын': 11,
#  'хомуурунньугун': 13,
#  'с': 2706,
#  'сыллааҕы': 102,
#  'биэрэпискэ': 3,
#  'саккырыыр': 9,
#  'улууһун': 353,
#  'нэһилиэнньэтэ': 75,
#  'көстөр': 583,
#  'сыллаахха': 1768,
#  'сэтинньигэ': 13,
#  'ороболууссуйэни': 1,
#  'утары': 475,
#  'сылларга': 472,
#  'бастаанньалаабыт': 1,
#  'дьону': 997,
#  'кытта': 2728,
#  'билсэр': 27,
#  'кинилэргэ': 113,
#  'комолоьор': 2,
#  'этэ': 2747,
#  'хаайыллыбыт': 11,
#  'муус': 359,
#  'устарга': 20,
#  'тройка': 2,
#  'суутунан': 15,
#  'сылга': 482,
#  'болдьохтоон': 5,
#  'кулуус': 1,
#  'хаайыытыгар': 12,
#  'ол': 7718,
#  'кэнниттэн': 1320,
#  'саха': 5821,
#  'сириттэн': 116,
#  'тоьо': 2,
#  'кыалларынан': 30,
#  'ыраах': 252,
#  'улэнэн': 3,
#  'конноруллэр': 1,
#  'лааырга': 1,
#  'утаарыллыбыт': 5,
#  'аҕа': 627,
#  'дойду': 1890,
#  'сэриитигэр': 100,
#  'үлэҕэ': 555,
#  'килбиэнин': 19,
#  'иһин': 2085,
#  'мэтээлинэн': 59,
#  'киһи': 13564,
#  'наҕараадаламмыта': 117,
#  'улуу': 733,
#  'сэриитин': 287,
#  'сылларыгар': 187,
#  'килбиэннээх': 49,
#  'үлэтин': 553,
#  'мэтээл': 71,
#  'кавалера': 54,
#  'атырдьах': 226,
#  'ыйын': 719,
#  'күнүгэр': 894,
#  'пулемеппун': 1,
#  'сүгэн': 18,
#  'сэриигэ': 269,
#  'киирдим': 4,
#  'атаакалааһан': 1,
#  'бардым': 1,
#  'материнское': 1,
#  'поле': 6,
#  'сэһэннэрэ': 19,
#  'ленин': 141,
#  'бириэмийэтин': 75,
#  'ылбыт': 302,
#  'повести': 1,
#  'гор': 2,
#  'и': 833,
#  'степей': 1,
#  'хомуурунньуга': 50,
#  'бэчээттэммиттэр': 16,
#  'сайыныгар': 31,
#  'уопсай': 299,
#  'куонкурсу': 1,
#  'ааһан': 112,
#  'культурология': 5,
#  'салаатыгар': 73,
#  'туттарсан': 10,
#  'киирбитэ': 267,
#  'гидрология': 5,
#  'геохимия': 1,
#  'өртүнэн': 20,
#  'байҕал': 113,
#  'соһуччу': 114,
#  'күн': 1310,
#  'күрэммитэ': 1,
#  'үйэ': 487,
#  'спордун': 79,
#  'лауреата': 103,
#  'аат': 373,
#  'бэриллибитэ': 25,
#  'үөһээ': 720,
#  'бүлүү': 345,
#  'өҥ': 51,
#  'буоруттан': 12,
#  'ср': 79,
#  'оройуона': 42,
#  'муниц': 10,
#  'бороҕон': 38,
#  'нэһилиэгэ': 120,
#  'муниципальнай': 23,
#  'тэриллии': 37,
#  'киинигэр': 68,
#  'томторго': 10,
#  'тыһыынча': 321,
#  'олорор': 1094,
#  'иэннээх': 85,
#  'тыһ': 268,
#  'минут': 1,
#  'сингл': 15,
#  'видеоклип': 10,
#  'тахсара': 100,
#  'ковлеков': 4,
#  'в': 722,
#  'никифоров': 53,
#  'съезд': 6,
#  'якутов': 28,
#  'г': 467,
#  'якутск': 54,
#  'сурунаал': 94,
#  'кулун': 176,
#  'тутар': 315,
#  'н': 627,
#  'е': 272,
#  'винокуров': 51,
#  'суруга': 60,
#  'тахсыбыт': 354,
#  'советизация': 1,
#  'эстония': 19,
#  'интеллектуалларын': 1,
#  'манифеста': 1,
#  'харахтаах': 40,
#  'ыт': 153,
#  'ейдебул': 11,
#  'туох': 1815,
#  'туhуттан': 4,
#  'уескээбитэй': 1,
#  'мииринэйгэ': 8,
#  'эр': 617,
#  'кэмэ': 537,
#  'суох': 4330,
#  'элбэх': 3347,
#  'дьахтар': 389,
#  'онон': 890,
#  'манан': 46,
#  'эрэ': 4989,
#  'баар': 3643,
#  'диир': 247,
#  'ыстаппаан': 20,
#  'оскуолатын': 208,
#  'бүтэрбит': 198,
#  'уу': 584,
#  'иччитэ': 73,
#  'хайа': 743,
#  'сир': 1132,
#  'сыллар': 176,
#  'саҥаларыттан': 5,
#  'сирэ': 394,
#  'казахстаны': 4,
#  'литературнай': 144,
#  'ситими': 11,
#  'олохтообута': 49,
#  'саас': 230,
#  'киһиэхэ': 1200,
#  'аҕыйаҕа': 19,
#  'эбвии': 1,
#  'ахш': 267,
#  'биофармацефтика': 1,
#  'тэрилтэтэ': 143,
#  'тэриллибит': 104,
#  'бэрэсидьиэнинэн': 7,
#  'дириэктэрдэр': 3,
#  'сэбиэттэрин': 19,
#  'чилиэнинэн': 78,
#  'ирландия': 8,
#  'саамай': 917,
#  'улахан': 4648,
#  'консалтинговай': 3,
#  'тэрилтэҕэ': 27,
#  'омук': 1314,
#  'дойдутугар': 249,
#  'аутсорсиҥ': 1,
#  'ыытар': 142,
#  'тэрилтэ': 270,
#  'эйсер': 2,
#  'ааҕыллар': 244,
#  'аан': 2572,
#  'бөдөҥ': 290,
#  'тэрилтэлэриттэн': 5,
#  'биирдэстэрэ': 308,
#  'үрүҥ': 854,
#  'көмүс': 322,
#  'призер': 9,
#  'буолла': 361,
#  'аага': 4,
#  'германия': 104,
#  'франция': 102,
#  'болгария': 10,
#  'кыттыылаах': 17,
#  'устуллубут': 1,
#  'сахалыы': 981,
#  'киинэ': 457,
#  'ону': 1710,
#  'ахмед': 9,
#  'тевфик': 5,
#  'паша': 12,
#  'аатынан': 702,
#  'эмиэ': 3166,
#  'биллэр': 1604,
#  'осман': 37,
#  'импиэрийэтин': 20,
#  'бүтэһик': 121,
#  'визирэ': 1,
#  'хампаанньаҕа': 30,
#  'россияттан': 12,
#  'сылдьар': 1706,
#  'бастакы': 1613,
#  'хампаанньа': 110,
#  'буолбута': 928,
#  'хампаанньаны': 20,
#  'сыллахха': 54,
#  'холбоспута': 15,
#  'алтынньы': 130,
#  'күнүттэн': 104,
#  'аатын': 339,
#  'уларыппыта': 9,
#  'дьиҥ': 68,
#  'аутомат': 4,
#  'чуор': 13,
#  'саалар': 19,
#  'ахсааннарыгар': 77,
#  'киирсэр': 259,
#  'атын': 2469,
#  'уотунан': 50,
#  'эстэр': 66,
#  'сэрии': 835,
#  'сэптэрин': 28,
#  'айан': 155,
#  'оҥорууларыгар': 3,
#  'олох': 1379,
#  'быhыытынан': 62,
#  'туттуллубута': 17,
#  'ырыаhыттары': 1,
#  'элбэхтэ': 188,
#  'бииргэ': 701,
#  'ылласпыта': 2,
#  'биллиитэ': 18,
#  'сингла': 7,
#  'дебютнай': 2,
#  'альбомыгар': 1,
#  'киирэр': 668,
#  'тахсыбытын': 33,
#  'саҕаланар': 255,
#  'бэйэтэ': 1651,
#  'тэрийбит': 77,
#  'икки': 3531,
#  'рекорд': 9,
#  'лейбллаах': 1,
#  'дизайнын': 4,
#  'оҥоруутун': 18,
#  'үлэтэ': 346,
#  'саҕаламмыта': 151,
#  'сулууспа': 22,
#  'ааҕытынан': 1,
#  'устар': 252,
#  'ыйыгар': 242,
#  'дойдуга': 965,
#  'миэстэни': 106,
#  'онтон': 2565,
#  'арассыыйаҕа': 150,
#  'ылара': 73,
#  'интернет': 61,
#  'маҕаһыын': 33,
#  'биир': 4081,
#  'буолар': 5653,
#  'хаастыҥылар': 3,
#  'этэрээттэрин': 11,
#  'кус': 54,
#  'семействотыгар': 1,
#  'көтөрдөрү': 29,
#  'ааттыыллар': 451,
#  'массыынанан': 38,
#  'тылбаас': 100,
#  'туттугун': 1,
#  'үнүстүрүмүөнүн': 1,
#  'быһыытынан': 898,
#  'бырайыак': 71,
#  'чэрчитинэн': 31,
#  'үөскээбитэ': 154,
#  'бастаан': 848,
#  'уруулуу': 38,
#  'тыллары': 258,
#  'тылбаастыырга': 12,
#  'анаан': 455,
#  'оҥоһуллубута': 45,
#  'оттон': 537,
#  'билигин': 2521,
#  'бэйэ': 709,
#  'бэйэлэригэр': 268,
#  'майгыннаспат': 1,
#  'тыллар': 604,
#  'паараларын': 1,
#  'хабар': 37,
#  'кыахтанна': 27,
#  'версиятынан': 6,
#  'хампааньыйа': 7,
#  'бастыҥ': 258,
#  'регионын': 2,
#  'издательарын': 1,
#  'испииhэгэр': 1,
#  'презентациятыгар': 1,
#  'стив': 5,
#  'джобс': 6,
#  'маннык': 1170,
#  'эппитэ': 62,
#  'технологиялар': 12,
#  'гуманитарнай': 21,
#  'наукалартан': 1,
#  'арахсыбат': 11,
#  'бу': 9089,
#  'быһаарыы': 405,
#  'посткомпьютернай': 2,
#  'эпоха': 6,
#  'устройстваларыгар': 2,
#  'өссө': 1417,
#  'кыдрдьык': 1,
#  'хампаанньата': 26,
#  'чуолкайдык': 163,
#  'саҥа': 1817,
#  'рынокка': 9,
#  'киирбит': 401,
#  'номнуо': 46,
#  'миллиардтааҕы': 1,
#  'ырыаны': 51,
#  'атыылабыттар': 1,
#  'электроннай': 57,
#  'кинигэ': 249,
#  'утаа': 30,
#  'босхо': 105,
#  'хачайданар': 1,
#  'кытаатыҥ': 1,
#  'киириҥ': 1,
#  'ааҕыҥ': 3,
#  'сэргээҥ': 2,
#  'сыаналааҥ': 1,
#  'үрдүк': 923,
#  'үөрэх': 896,
#  'тэрилтэлэрин': 68,
#  'рейтинигэр': 29,
#  'арассыыйа': 469,
#  'үөрэҕин': 999,
#  'тэрилтэлэригэр': 73,
#  'ксму': 5,
#  'миэстэлээх': 37,
#  'мэдиссиинэ': 68,
#  'татарстан': 14,
#  'өрөспүүбүлүкэтигэр': 19,
#  'арму': 1,
#  'иһигэр': 701,
#  'киирэн': 958,
#  'университеттарын': 8,
#  'тутулуга': 221,
#  'нсму': 2,
#  'миэстэлэрдээх': 7,
#  'төр': 35,
#  'өлб': 6,
#  'бэй': 8,
#  'ыйа': 80,
#  'үйэҕэ': 338,
#  'кырыым': 30,
#  'ханствотын': 10,
#  'биллиилээх': 274,
#  'полководеһа': 2,
#  'политическай': 70,
#  'диэйэтэлэ': 70,
#  'кыттааччы': 61,
#  'дойдуларын': 84,
#  'бүтүн': 246,
#  'иэннэрэ': 17,
#  'млн': 124,
#  'км': 793,
#  'олохтоохторун': 277,
#  'ахсаана': 1234,
#  'киhи': 238,
#  'дьонун': 1072,
#  'ааттаах': 423,
#  'бюрота': 4,
#  'барытыгар': 167,
#  'үлэлиир': 749,
#  'миллард': 1,
#  'долларга': 13,
#  'хампааньыйага': 3,
#  'атыламмыта': 1,
#  'үлэлиһиини': 1,
#  'быспыта': 6,
#  'ча': 97,
#  'кэлин': 1218,
#  'эуропа': 65,
#  'омуктарын': 83,
#  'тылларынан': 146,
#  'интервьюлары': 1,
#  'биэрбиттэрэ': 30,
#  'бөлөх': 189,
#  'үчүгэй': 2819,
#  'ырыаларынан': 4,
#  'хомуурунньук': 16,
#  'таһаарбыта': 109,
#  'бастың': 8,
#  'поп': 17,
#  'группата': 9,
#  'дуэта': 1,
#  'үҥкүү': 38,
#  'бөлөҕө': 66,
#  'номинацияларга': 1,
#  'тиксибитэ': 18,
#  'да': 7264,
#  'баалы': 1,
#  'ылбатаҕа': 6,
#  'ленинград': 42,
#  'бөлөххө': 111,
#  'сергей': 98,
#  'шнуров': 1,
#  'ырыаһыкка': 2,
#  'биэрэллэригэр': 9,
#  'көрдөспүтэ': 10,
#  'хит': 15,
#  'парадтарыгар': 1,
#  'эрэллээхтиик': 1,
#  'бастыыллара': 1,
#  'менеджмена': 1,
#  'бастайааннай': 15,
#  'тохтоторун': 7,
#  'туһунан': 1581,
#  'официалык': 3,
#  'сайт': 18,
#  'блогар': 2,
#  'суруйбута': 218,
#  'менеджмента': 1,
#  'тахсыахтаах': 12,
#  'управление': 11,
#  'отбросами': 3,
#  'альбом': 91,
#  'весёлые': 1,
#  'улыбки': 1,
#  'диэҥҥэ': 152,
#  'уларытыллыбытын': 1,
#  'официаллык': 31,
#  'сайтыгар': 2,
#  'суруллубута': 29,
#  'үлэлииллэрин': 20,
#  'тохтоппуттара': 11,
#  'урукку': 597,
#  'айар': 276,
#  'таптыыр': 60,
#  'дьоно': 926,
#  'аҕыйаан': 144,
#  'испитэ': 59,
#  'футболунан': 5,
#  'дьарыктаммыта': 59,
#  'төрөөбүт': 746,
#  'аата': 1661,
#  'кэтэх': 29,
#  'уулусса': 44,
#  'уолаттара': 52,
#  'ы': 29,
#  'сүрүннээн': 157,
#  'дьон': 5614,
#  'үбүлүүр': 5,
#  'кини': 3326,
#  'араастара': 23,
#  'сс': 185,
#  'канаалга': 3,
#  'шоуга': 3,
#  'ыллаан': 20,
#  'пол': 11,
#  'маккартнины': 1,
#  'бьоркы': 1,
#  'кыттыбыта': 109,
#  'канаалын': 2,
#  'репортёра': 1,
#  'уруккута': 44,
#  'байыаннай': 231,
#  'толору': 452,
#  'статуһун': 10,
#  'сэртипикээтин': 1,
#  'ыларга': 49,
#  'олохтуур': 31,
#  'дуогабарын': 7,
#  'менеджердар': 1,
#  'акциялаахтар': 1,
#  'тустарыгар': 37,
#  'буолбакка': 306,
#  'үлэһиттэр': 213,
#  'тулалыыр': 105,
#  'уопсастыба': 84,
#  'интэриэстэрин': 14,
#  'көрөллөрүн': 8,
#  'курдук': 3942,
#  'уларытыахтаах': 1,
#  'психологическай': 18,
#  'эротическай': 1,
#  'ситимнээх': 65,
#  'ролевой': 1,
#  'оонньуу': 185,
#  'сексуальнай': 7,
#  'көҕүтүүлээх': 1,
#  'охсуһуулаах': 10,
#  'охсуһардаах': 1,
#  'саайсыылардаах': 1,
#  'тустааһыннаах': 1,
#  'ыарыы': 390,
#  'оҥорооһуннаах': 1,
#  'дьаһайааччы': 2,
#  'толорооччу': 23,
#  'оруоллаах': 35,
#  'киэҥник': 485,
#  'атыылыыр': 55,
#  'марка': 6,
#  'сирэйэ': 29,
#  'америка': 173,
#  'маҕаһыына': 6,
#  'мебель': 1,
#  'араас': 2384,
#  'дьиэҕэ': 138,
#  'аналлаах': 763,
#  'тэриллэри': 39,
#  'эн': 118,
#  'ырыалаах': 13,
#  'кыайбыта': 32,
#  'беллиҥкэт': 1,
#  'көҥүл': 251,
#  'түмсүү': 50,
#  'кистэлэҥ': 94,
#  'дьыалалары': 64,
#  'арыйар': 112,
#  'дьоҥҥо': 990,
#  'көрдөрөр': 380,
#  'оннук': 459,
#  'урукута': 2,
#  'американскай': 17,
#  'билиҥҥитэ': 34,
#  'финскэй': 5,
#  'корпорация': 13,
#  'чинчийэр': 126,
#  'телекоммункация': 1,
#  'компьютернай': 23,
#  'система': 60,
#  'киинин': 55,
#  'уобалаһа': 36,
#  'коммерция': 3,
#  'бигкоммерц': 1,
#  'бизнеһынан': 1,
#  'дьарыгырар': 10,
#  'парадыгар': 5,
#  'аныгы': 541,
#  'рок': 39,
#  'ырыалар': 28,
#  'быыстарыгар': 50,
#  'нэдиэлэни': 2,
#  'быһа': 360,
#  'олохтоммут': 42,
#  'католик': 11,
#  'оскуолатыгар': 265,
#  'үөрэммит': 406,
#  'хампаанньаларга': 3,
#  'социаль': 2,
#  'экология': 12,
#  'ирдэбиллэрин': 4,
#  'киритиэрийдэригэр': 2,
#  'сөп': 4560,
#  'түбэһэр': 450,
#  'сэртипикээттэри': 1,
#  'оҥорбут': 462,
#  'или': 31,
#  'хампаанньалар': 16,
#  'көрүҥнэрин': 35,
#  'барыыстаах': 6,
#  'блэкрок': 2,
#  'планета': 44,
#  'үрдүнэн': 347,
#  'инвестиционнай': 7,
#  'харчыта': 27,
#  'триллион': 7,
#  'тэҥнэһэр': 57,
#  'эбэтэр': 2642,
#  'бүджетын': 1,
#  'иккитэ': 84,
#  'үстэ': 47,
#  'холбообут': 8,
#  'саҕа': 44,
#  'гамбургер': 4,
#  'оҥорор': 2288,
#  'ырыа': 224,
#  'оҥорорунан': 18,
#  'агентство': 4,
#  'этэринэн': 185,
#  'бааннар': 12,
#  'арыларыгар': 1,
#  'ситимин': 35,
#  'эргииригэр': 11,
#  'ыам': 199,
#  'ыйыттан': 56,
#  'дылы': 545,
#  'сылынан': 91,
#  'иннинэ': 563,
#  'көмөтүнэн': 267,
#  'пульт': 1,
#  'джойстик': 1,
#  'холбонуон': 1,
#  'сырыылаах': 18,
#  'палубалаах': 1,
#  'кэтит': 40,
#  'фюзеляжтаах': 1,
#  'пассажир': 7,
#  'таһар': 25,
#  'сөмөлүөт': 7,
#  'оҕустар': 5,
#  'дойдулара': 70,
#  'киин': 604,
#  'европаҕа': 106,
#  'билиҥҥи': 563,
#  'чехия': 27,
#  'арҕаа': 491,
#  'эҥэригэр': 4,
#  'историечскай': 1,
#  'уобалас': 139,
#  'ааттанар': 1093,
#  'эрдэҕиттэн': 565,
#  'диалект': 17,
#  'тыл': 2362,
#  'чугаһатыллыбыттара': 1,
#  'иккис': 734,
#  'студийнай': 2,
#  'альбомун': 18,
#  'таьаарбыта': 4,
#  'туйахтаах': 5,
#  'дьиэ': 690,
#  'кыыла': 15,
#  'роботтары': 4,
#  'братс': 1,
#  'бургер': 2,
#  'сирин': 1054,
#  'сетевой': 7,
#  'ресторана': 7,
#  'сүрүн': 1224,
#  'астара': 30,
#  'хотдог': 1,
#  'бургердар': 1,
#  'картофель': 2,
#  'фри': 2,
#  'киҥ': 1,
#  'тэн': 107,
#  'тахса': 507,
#  'тыыһынча': 20,
#  'рестораннаах': 1,
#  'дойдуларыгар': 155,
#  'олор': 148,
#  'сиригэр': 1029,
#  'биитэр': 76,
#  'дыбарыас': 6,
#  'мэчиэтэ': 4,
#  'бахчисарайга': 2,
#  'хан': 57,
#  'дыбарыаһын': 6,
#  'алексеев': 90,
#  'өксөкүлээх': 26,
#  'өлөксөй': 32,
#  'бэйэтин': 1842,
#  'ырыаларыттан': 3,
#  'таҥыллыбыт': 4,
#  'оҥорон': 1161,
#  'атыыга': 60,
#  'илик': 339,
#  'шутер': 4,
#  'онньуу': 4,
#  'сиэрийэ': 5,
#  'тохсус': 36,
#  'оонньуута': 27,
#  'сиквела': 1,
#  'буолбут': 1200,
#  'дьоппуон': 149,
#  'тылын': 909,
#  'ааҥллыы': 4,
#  'формата': 18,
#  'хоруона': 3,
#  'тылбаастанар': 37,
#  'тиhэх': 15,
#  'уон': 276,
#  'устата': 546,
#  'атыытынан': 4,
#  'массыына': 140,
#  'ыттар': 33,
#  'биистэрин': 40,
#  'уустарыгар': 20,
#  'хаппыстыҥылар': 1,
#  'уустар': 85,
#  'бөлөхтөрө': 53,
#  'бириэмэтэ': 19,
#  'бүппүтүгэр': 2,
#  'уолаттар': 139,
#  'бырагыраамманы': 3,
#  'алдьаппыттара': 3,
#  'тоҕо': 333,
#  'тас': 372,
#  'тахсарый': 2,
#  'уопсайа': 85,
#  'тылынан': 535,
#  'вещаниятын': 2,
#  'континеннарыгар': 4,
#  'атомная': 1,
#  'электростанция': 10,
#  'үс': 1008,
#  'реактора': 1,
#  'кинини': 468,
#  'сабар': 11,
#  'саркофаг': 1,
#  'пааматынньык': 24,
#  'тымныы': 265,
#  'чэйгэ': 7,
#  'олохтоох': 525,
#  'дисиэрти': 1,
#  'фэнъюа': 1,
#  'нь': 18,
#  'кит': 7,
#  'трад': 2,
#  'кытай': 421,
#  'ноутбуктары': 1,
#  'планшеттары': 3,
#  'компьютердары': 8,
#  'таһаарар': 289,
#  'ханаалга': 5,
#  'метрополичном': 1,
#  'кафе': 1,
#  'сиэрийэлээх': 16,
#  'сэрийээлэ': 3,
#  'тахсыбыта': 263,
#  'аатыгар': 61,
#  'киирэлээр': 1,
#  'буулдьа': 25,
#  'калибра': 2,
#  'гильза': 3,
#  'уһуна': 284,
#  'закраината': 1,
#  'баара': 558,
#  'суоҕа': 286,
#  'дойдуларга': 236,
#  'баанынан': 4,
#  'америкаҕа': 72,
#  'шаарын': 16,
#  'тутаах': 214,
#  'баай': 599,
#  'харчылаах': 30,
#  'баана': 21,
#  'ситибанк': 1,
#  'рус': 3,
#  'филиаллаах': 8,
#  'айымньыга': 31,
#  'ааптар': 51,
#  'ханна': 332,
#  'дьоллоох': 49,
#  'куоратын': 46,
#  'ойуулуур': 53,
#  'клабхаус': 1,
#  'социальнай': 145,
#  'ситим': 77,
#  'куолаһынан': 16,
#  'хлористай': 1,
#  'натрий': 21,
#  'таас': 335,
#  'туус': 67,
#  'аатанар': 2,
#  'аһыыр': 191,
#  'бородуукта': 9,
#  'мин': 457,
#  'толкуйдуубун': 3,
#  'дьиҥнээхпин': 1,
#  'криптобиржа': 1,
#  'интерпретатор': 1,
#  'сорох': 811,
#  'хамаандалара': 4,
#  'кыһыл': 632,
#  'от': 588,
#  'күөҕэ': 50,
#  'сукунаны': 4,
#  'хара': 831,
#  'саһыл': 38,
#  'тыстарын': 1,
#  'тыҥырахтарын': 2,
#  'кытары': 274,
#  'аттараллара': 1,
#  'өҥнөөх': 232,
#  'барчаны': 1,
#  'дьүөрэлээн': 10,
#  'тигэллэрэ': 12,
#  'сэттис': 40,
#  'көлүөнэтэ': 5,
#  'сылтан': 312,
#  'собуот': 20,
#  'кэмбиэйэригэр': 1,
#  'турбута': 43,
#  'ис': 650,
#  'хоhоонунан': 2,
#  'террористары': 2,
#  'утарар': 47,
#  'террористар': 1,
#  'хамаандаларын': 2,
#  'утарылаhыылара': 1,
#  'кыыл': 259,
#  'бронхатын': 1,
#  'тыҥатын': 5,
#  'органнарын': 15,
#  'бастатан': 59,
#  'туран': 439,
#  'алдьатар': 58,
#  'устунан': 15,
#  'тыҥа': 15,
#  'сытыйыытыгар': 1,
#  'некроз': 2,
#  'тириэрдиэн': 121,
#  'пневмония': 5,
#  'коронавируһанан': 1,
#  'ыалдьыбыт': 93,
#  'өлөр': 112,
#  'кутталга': 11,
#  'ыарахан': 493,
#  'респираторнай': 2,
#  'тыынар': 200,
#  'уорганнарын': 18,
#  'дьаҥныыр': 1,
#  'инфекция': 5,
#  'реальнай': 29,
#  'былаана': 13,
#  'тарҕаныыта': 23,
#  'өлүү': 95,
#  'дьиҥнээх': 213,
#  'таһыма': 100,
#  'биллибэккэ': 27,
#  'хаалар': 457,
#  'үксэ': 126,
#  'туспа': 1307,
#  'кыра': 3057,
#  'чип': 3,
#  'гына': 418,
#  'оҥоhуллаллар': 1,
#  'президенигэр': 2,
#  'бэлиитикэтин': 18,
#  'сэбиэтин': 148,
#  'бэрэссэдээтэлин': 26,
#  'солбуйааччыта': 32,
#  'ийэ': 1471,
#  'сыла': 69,
#  'реактивнай': 2,
#  'самолеттары': 6,
#  'туттубут': 31,
#  'авиахампаанньа': 2,
#  'хаһыаты': 17,
#  'сурунал': 2,
#  'көрөрүгэр': 14,
#  'көмөлөспүт': 38,
#  'кумах': 73,
#  'томтордоро': 1,
#  'дюналар': 2,
#  'м': 829,
#  'үрдүктээхтэр': 7,
#  'тростнига': 1,
#  'саахар': 30,
#  'сүбүөкүлэ': 4,
#  'саахардаах': 5,
#  'үүнэйилэртэн': 1,
#  'сүмэһиннэнэр': 1,
#  'ахеменид': 3,
#  'империятыгар': 16,
#  'киирбиттэрэ': 57,
#  'сака': 28,
#  'сатрапия': 2,
#  'буолбуттара': 284,
#  'чурапчы': 164,
#  'орто': 970,
#  'базатыгар': 17,
#  'педагогическай': 99,
#  'кылааска': 53,
#  'үөрэнэн': 471,
#  'начальнай': 24,
#  'кылаас': 88,
#  'учууталын': 17,
#  'идэтин': 78,
#  'ылар': 667,
#  'сүөһү': 346,
#  'сороҕор': 263,
#  'холбоон': 134,
#  'бэлиэтээн': 145,
#  'тутталлар': 234,
#  'өрөспүүбүлүкэтин': 292,
#  'бэрисидиэнин': 1,
#  'бириэмийэтэ': 12,
#  'сө': 156,
#  'дьоҕус': 57,
#  'урбааны': 3,
#  'сайыннарыыга': 32,
#  'кылаатын': 27,
#  'норуотун': 210,
#  'хаһаайыстыбатын': 202,
#  'үтүөлээх': 343,
#  'үлэһитэ': 236,
#  'тыатын': 34,
#  'туйгуна': 118,
#  'тутааччыта': 9,
#  'урут': 515,
#  'асср': 304,
#  'учуутала': 123,
#  'эргиэнин': 8,
#  'бочуоттаах': 159,
#  'ньуурун': 29,
#  'хайалаах': 85,
#  'сирдэр': 85,
#  'сирдэргэ': 144,
#  'хорутан': 9,
#  'бурдук': 91,
#  'оҕуруот': 84,
#  'ыһыытын': 2,
#  'пропагандалаабыт': 3,
#  'тыа': 473,
#  'хаһаайыстыбатыгар': 35,
#  'техниканы': 11,
#  'маҥнайгынан': 25,
#  'боруобалаан': 109,
#  'туһанарыгар': 6,
#  'холобур': 625,
#  'этии': 1054,
#  'олус': 3301,
#  'таба': 929,
#  'буолбутун': 176,
#  'биллэрэр': 872,
#  'бырабыыталыстыбатын': 16,
#  'билим': 144,
#  'судаарыстыбыннай': 4,
#  'кэмитиэтигэр': 13,
#  'салаатын': 160,
#  'салайааччыта': 119,
#  'уол': 507,
#  'оҕону': 1151,
#  'иитэрэ': 11,
#  'иэнэ': 343,
#  'км²': 234,
#  'на': 96,
#  'билимҥэ': 21,
#  'ситиһиилэрин': 40,
#  'бэлиэлээх': 24,
#  'ордук': 3064,
#  'программалааhын': 7,
#  'тылларыттан': 62,
#  'министерствотын': 12,
#  'методика': 3,
#  'начальнига': 12,
#  'кылаабынай': 68,
#  'специалииһа': 1,
#  'софтуэр': 3,
#  'индустриятыгар': 6,
#  'туттуллар': 655,
#  'драматург': 35,
#  'туобулаахап': 2,
#  'рецензенинэн': 1,
#  'үлэлээбитэ': 589,
#  'церемониятыгар': 4,
#  'тату': 11,
#  'легенда': 4,
#  'наҕараадаҕа': 7,
#  'ситиһиитин': 20,
#  'хатылаан': 123,
#  'биһирэбили': 16,
#  'ылбыта': 382,
#  'альбомнан': 1,
#  'радиостанцияларга': 1,
#  'анаммыт': 145,
#  'промо': 4,
#  'ситиһиитэ': 63,
#  'кыракый': 57,
#  'ааҥл': 17,
#  'позицияҕа': 1,
#  'германияҕа': 62,
#  'дьоппуоҥҥа': 15,
#  'миэстэлэргэ': 16,
#  'ситиспитэ': 26,
#  'альбомы': 1,
#  'өйөөн': 12,
#  'тур': 17,
#  'оңорор': 5,
#  'программата': 8,
#  'сүрэхпит': 2,
#  ...}

# %%
from operator import itemgetter
res = sorted(new_dct.items(), key=itemgetter(1), reverse=True)
res
# Out:
# [('диэн', 16757),
#  ('уонна', 16435),
#  ('киһи', 13564),
#  ('бу', 9089),
#  ('ол', 7718),
#  ('да', 7264),
#  ('саха', 5821),
#  ('буолар', 5653),
#  ('дьон', 5614),
#  ('эрэ', 4989),
#  ('улахан', 4648),
#  ('сөп', 4560),
#  ('суох', 4330),
#  ('биир', 4081),
#  ('оҕо', 4025),
#  ('курдук', 3942),
#  ('баар', 3643),
#  ('икки', 3531),
#  ('элбэх', 3347),
#  ('кини', 3326),
#  ('олус', 3301),
#  ('буолан', 3274),
#  ('баран', 3207),
#  ('эмиэ', 3166),
#  ('ордук', 3064),
#  ('кыра', 3057),
#  ('санаа', 3001),
#  ('үчүгэй', 2819),
#  ('куһаҕан', 2805),
#  ('сахалар', 2783),
#  ('этэ', 2747),
#  ('кытта', 2728),
#  ('с', 2706),
#  ('сыл', 2643),
#  ('эбэтэр', 2642),
#  ('санаата', 2630),
#  ('аан', 2572),
#  ('онтон', 2565),
#  ('бары', 2524),
#  ('билигин', 2521),
#  ('атын', 2469),
#  ('араас', 2384),
#  ('тыл', 2362),
#  ('оҥорор', 2288),
#  ('өй', 2228),
#  ('өйө', 2226),
#  ('иһин', 2085),
#  ('кэмҥэ', 2065),
#  ('айыы', 2058),
#  ('аһара', 1998),
#  ('эбит', 1897),
#  ('дойду', 1890),
#  ('иһэр', 1875),
#  ('былыргы', 1857),
#  ('бэйэтин', 1842),
#  ('саҥа', 1817),
#  ('туох', 1815),
#  ('сыллаахха', 1768),
#  ('таҥара', 1729),
#  ('ону', 1710),
#  ('сылдьар', 1706),
#  ('хас', 1692),
#  ('ити', 1681),
#  ('аата', 1661),
#  ('бэйэтэ', 1651),
#  ('ханнык', 1627),
#  ('бастакы', 1613),
#  ('биллэр', 1604),
#  ('барыта', 1601),
#  ('туһунан', 1581),
#  ('ийэ', 1471),
#  ('эмэ', 1464),
#  ('өссө', 1417),
#  ('олох', 1379),
#  ('сыыһа', 1350),
#  ('кэмигэр', 1328),
#  ('кэнниттэн', 1320),
#  ('омук', 1314),
#  ('баҕа', 1311),
#  ('күн', 1310),
#  ('турар', 1310),
#  ('туспа', 1307),
#  ('буола', 1290),
#  ('киһини', 1284),
#  ('тугу', 1278),
#  ('санаатын', 1267),
#  ('олоххо', 1250),
#  ('ахсаана', 1234),
#  ('сүрүн', 1224),
#  ('кэлин', 1218),
#  ('саҥаны', 1216),
#  ('буолуу', 1215),
#  ('хаһан', 1213),
#  ('сайдан', 1213),
#  ('киһиэхэ', 1200),
#  ('буолбут', 1200),
#  ('онно', 1198),
#  ('быһаарар', 1189),
#  ('маннык', 1170),
#  ('баҕарар', 1164),
#  ('оҥорон', 1161),
#  ('даҕаны', 1161),
#  ('оҕону', 1151),
#  ('диэри', 1135),
#  ('сир', 1132),
#  ('буоллаҕына', 1126),
#  ('куһаҕаны', 1112),
#  ('үчүгэйи', 1103),
#  ('кинилэр', 1096),
#  ('олорор', 1094),
#  ('ааттанар', 1093),
#  ('кут', 1085),
#  ('уһун', 1079),
#  ('а', 1074),
#  ('дьонун', 1072),
#  ('улаатан', 1069),
#  ('бэйэлэрин', 1055),
#  ('үөрэҕэ', 1055),
#  ('сирин', 1054),
#  ('этии', 1054),
#  ('айыыны', 1054),
#  ('кыайан', 1043),
#  ('сиригэр', 1029),
#  ('кэннэ', 1017),
#  ('үс', 1008),
#  ('үөрэҕин', 999),
#  ('дьону', 997),
#  ('элбэхтик', 997),
#  ('дьоҥҥо', 990),
#  ('сахалыы', 981),
#  ('орто', 970),
#  ('дойдуга', 965),
#  ('киирэн', 958),
#  ('эдэр', 946),
#  ('хайдах', 937),
#  ('санаалара', 934),
#  ('таба', 929),
#  ('буолбута', 928),
#  ('дьоно', 926),
#  ('үрдүк', 923),
#  ('саамай', 917),
#  ('тылын', 909),
#  ('кэлэр', 908),
#  ('быһыытынан', 898),
#  ('үөрэх', 896),
#  ('күнүгэр', 894),
#  ('онон', 890),
#  ('биллэрэр', 872),
#  ('эрээри', 871),
#  ('олоҕун', 859),
#  ('куорат', 856),
#  ('үрүҥ', 854),
#  ('бастаан', 848),
#  ('үлэ', 847),
#  ('таһынан', 841),
#  ('манна', 836),
#  ('сэрии', 835),
#  ('и', 833),
#  ('хара', 831),
#  ('кэлэн', 831),
#  ('м', 829),
#  ('диэки', 826),
#  ('өйүн', 820),
#  ('сылдьан', 815),
#  ('сорох', 811),
#  ('тус', 805),
#  ('санааны', 800),
#  ('км', 793),
#  ('сэбиэскэй', 779),
#  ('сиргэ', 776),
#  ('көрөн', 775),
#  ('аналлаах', 763),
#  ('үгүс', 763),
#  ('барар', 757),
#  ('үлэлиир', 749),
#  ('оҥоруу', 749),
#  ('буолара', 748),
#  ('санаатыгар', 747),
#  ('төрөөбүт', 746),
#  ('гынан', 744),
#  ('хайа', 743),
#  ('тахсар', 743),
#  ('төһө', 742),
#  ('иккис', 734),
#  ('улуу', 733),
#  ('эрдэҕинэ', 724),
#  ('халты', 724),
#  ('в', 722),
#  ('үөһээ', 720),
#  ('айылҕа', 720),
#  ('ыйын', 719),
#  ('күүстээх', 712),
#  ('өттүгэр', 711),
#  ('буолаллар', 710),
#  ('бэйэ', 709),
#  ('өйүгэр', 707),
#  ('туһалаах', 706),
#  ('бааллар', 705),
#  ('кута', 705),
#  ('барытын', 703),
#  ('аатынан', 702),
#  ('бииргэ', 701),
#  ('иһигэр', 701),
#  ('үөскээн', 698),
#  ('арааран', 697),
#  ('ылан', 692),
#  ('дьиэ', 690),
#  ('ураты', 689),
#  ('үөскүүр', 689),
#  ('тылы', 683),
#  ('буор', 677),
#  ('оҕолорун', 671),
#  ('билэр', 670),
#  ('буоларын', 670),
#  ('уус', 670),
#  ('киирэр', 668),
#  ('ылар', 667),
#  ('үөрэтии', 666),
#  ('быһыылары', 665),
#  ('сытар', 658),
#  ('үөскэтэр', 656),
#  ('туттуллар', 655),
#  ('кыахтаах', 653),
#  ('хос', 652),
#  ('тириэрдэр', 651),
#  ('ис', 650),
#  ('салгыы', 641),
#  ('биһиги', 641),
#  ('итинник', 640),
#  ('санааларын', 639),
#  ('үөскээбит', 639),
#  ('былыр', 638),
#  ('былыргыттан', 638),
#  ('үөрэтэр', 634),
#  ('үгэс', 633),
#  ('куоракка', 633),
#  ('кыһыл', 632),
#  ('аҕа', 627),
#  ('н', 627),
#  ('аҕыйах', 626),
#  ('холобур', 625),
#  ('биэрэр', 625),
#  ('эр', 617),
#  ('арыгы', 617),
#  ('хаан', 616),
#  ('үлэни', 614),
#  ('санаалаах', 613),
#  ('омуктар', 612),
#  ('киһилии', 611),
#  ('түргэнник', 610),
#  ('хайаан', 607),
#  ('тыллар', 604),
#  ('киин', 604),
#  ('тэҥэ', 603),
#  ('куруук', 602),
#  ('баай', 599),
#  ('билэн', 599),
#  ('маҥнай', 599),
#  ('кыаҕа', 598),
#  ('былаас', 598),
#  ('урукку', 597),
#  ('нуучча', 590),
#  ('үлэлээбитэ', 589),
#  ('от', 588),
#  ('уу', 584),
#  ('быстах', 584),
#  ('көстөр', 583),
#  ('буолуон', 581),
#  ('тыла', 578),
#  ('өйдөрө', 577),
#  ('биирдэ', 573),
#  ('илин', 572),
#  ('өлбүт', 569),
#  ('эрдэҕиттэн', 565),
#  ('салгын', 564),
#  ('иннинэ', 563),
#  ('билиҥҥи', 563),
#  ('үтүө', 560),
#  ('оҥоро', 560),
#  ('биирдии', 559),
#  ('улаханнык', 559),
#  ('бэйэлэрэ', 559),
#  ('баара', 558),
#  ('быһаччы', 558),
#  ('төрүт', 558),
#  ('үлэҕэ', 555),
#  ('кыахтанар', 554),
#  ('үлэтин', 553),
#  ('буолууга', 552),
#  ('аны', 550),
#  ('олоҕор', 549),
#  ('устата', 546),
#  ('дылы', 545),
#  ('аайы', 543),
#  ('ыла', 542),
#  ('аныгы', 541),
#  ('олохторун', 541),
#  ('кэмэ', 537),
#  ('оттон', 537),
#  ('тылынан', 535),
#  ('оҕолор', 535),
#  ('буоллар', 533),
#  ('россия', 532),
#  ('сылдьыбыт', 531),
#  ('быһыы', 531),
#  ('сылдьаллар', 530),
#  ('олохтоох', 525),
#  ('арыгыны', 525),
#  ('наада', 517),
#  ('урут', 515),
#  ('сотору', 512),
#  ('өрүттээх', 510),
#  ('тахса', 507),
#  ('уол', 507),
#  ('өрүс', 504),
#  ('соҕуруу', 503),
#  ('тухары', 502),
#  ('үөрэҕи', 500),
#  ('быһыытын', 499),
#  ('сүр', 498),
#  ('ким', 496),
#  ('ыарахан', 493),
#  ('хоту', 493),
#  ('өр', 493),
#  ('уларыйан', 492),
#  ('арҕаа', 491),
#  ('тиийэн', 488),
#  ('үйэ', 487),
#  ('быһаарыллар', 487),
#  ('дуу', 487),
#  ('киэҥник', 485),
#  ('п', 485),
#  ('сылга', 482),
#  ('салайар', 480),
#  ('тутулуктаах', 479),
#  ('тылыгар', 477),
#  ('быһыылаах', 477),
#  ('утары', 475),
#  ('төрөппүттэр', 475),
#  ('тыа', 473),
#  ('сылларга', 472),
#  ('үөрэнэн', 471),
#  ('өйү', 470),
#  ('арассыыйа', 469),
#  ('кинини', 468),
#  ('букатын', 468),
#  ('г', 467),
#  ('син', 464),
#  ('кыыс', 463),
#  ('оҥорбут', 462),
#  ('бас', 462),
#  ('тутан', 461),
#  ('үлэлээбит', 461),
#  ('улуус', 461),
#  ('этэллэр', 460),
#  ('оннук', 459),
#  ('киинэ', 457),
#  ('мин', 457),
#  ('хаалар', 457),
#  ('анаан', 455),
#  ('суолталаах', 455),
#  ('оҕолоро', 454),
#  ('толору', 452),
#  ('ааттыыллар', 451),
#  ('үлэһит', 451),
#  ('истэҕинэ', 451),
#  ('иһэн', 451),
#  ('киэҥ', 451),
#  ('маны', 451),
#  ('түбэһэр', 450),
#  ('оҕото', 445),
#  ('киһитэ', 443),
#  ('буолууну', 443),
#  ('кэм', 443),
#  ('сатаан', 443),
#  ('эт', 440),
#  ('туран', 439),
#  ('улаатар', 439),
#  ('көрөр', 435),
#  ('хаалбыт', 435),
#  ('сахаларга', 432),
#  ('өйдөөх', 428),
#  ('этин', 427),
#  ('үөрэнэр', 426),
#  ('хотугу', 426),
#  ('мас', 426),
#  ('николай', 426),
#  ('ааттаах', 423),
#  ('өс', 423),
#  ('туһугар', 423),
#  ('кытай', 421),
#  ('ссрс', 421),
#  ('хаалан', 420),
#  ('гына', 418),
#  ('норуот', 418),
#  ('үөрэтэн', 418),
#  ('өрө', 415),
#  ('тыыннаах', 414),
#  ('эрэр', 414),
#  ('ыал', 413),
#  ('суол', 412),
#  ('аҕата', 409),
#  ('тахсан', 408),
#  ('үөрэммит', 406),
#  ('ас', 406),
#  ('быһаарыы', 405),
#  ('арай', 404),
#  ('үрдүкү', 403),
#  ('иҥэн', 403),
#  ('билии', 402),
#  ('ирдэнэр', 402),
#  ('киирбит', 401),
#  ('кутун', 401),
#  ('эбиллэн', 400),
#  ('д', 399),
#  ('ый', 398),
#  ('сэмэй', 396),
#  ('биллибэт', 396),
#  ('сирэ', 394),
#  ('тимир', 393),
#  ('бэлиэтиир', 392),
#  ('ыарыы', 390),
#  ('дьахтар', 389),
#  ('булан', 388),
#  ('сайдыыны', 387),
#  ('тойон', 384),
#  ('ылбыта', 382),
#  ('үчүгэйдик', 381),
#  ('биэрэн', 381),
#  ('санааҕа', 381),
#  ('көрдөрөр', 380),
#  ('үөрэхтэрэ', 380),
#  ('оскуола', 377),
#  ('ситэ', 376),
#  ('олорон', 376),
#  ('аат', 373),
#  ('түмүгэр', 373),
#  ('тас', 372),
#  ('буолуута', 372),
#  ('дьэ', 372),
#  ('тиийэр', 372),
#  ('олорбут', 371),
#  ('этилэр', 370),
#  ('билбэт', 369),
#  ('олоҕу', 368),
#  ('элбээн', 368),
#  ('күөл', 365),
#  ('уола', 364),
#  ('күүскэ', 364),
#  ('иһэллэр', 364),
#  ('табыллар', 364),
#  ('кэмнэргэ', 364),
#  ('кылгас', 363),
#  ('бүтүө', 363),
#  ('кэнники', 362),
#  ('буолла', 361),
#  ('быһа', 360),
#  ('муус', 359),
#  ('туттар', 359),
#  ('аймах', 359),
#  ('сатыыр', 357),
#  ('тулуурдаах', 357),
#  ('быһыыны', 357),
#  ('оҕолору', 357),
#  ('тахсыбыт', 354),
#  ('түөрт', 354),
#  ('оҥорбот', 354),
#  ('үлэлии', 354),
#  ('улууһун', 353),
#  ('төрөөбүтэ', 353),
#  ('сиинин', 352),
#  ('сири', 350),
#  ('сиинэ', 350),
#  ('үрдүнэн', 347),
#  ('көрсүө', 347),
#  ('үлэтэ', 346),
#  ('сүөһү', 346),
#  ('буолуо', 346),
#  ('билэллэр', 346),
#  ('сиэри', 346),
#  ('бүлүү', 345),
#  ('үтүөлээх', 343),
#  ('иэнэ', 343),
#  ('сайдыылаах', 343),
#  ('эбии', 342),
#  ('барыларын', 341),
#  ('аатын', 339),
#  ('илик', 339),
#  ('к', 339),
#  ('үйэҕэ', 338),
#  ('өттүнэн', 338),
#  ('үрдүгэр', 337),
#  ('таас', 335),
#  ('тоҕо', 333),
#  ('ханна', 332),
#  ('бэрт', 328),
#  ('олоҕо', 327),
#  ('чилиэнэ', 326),
#  ('өйдөбүл', 326),
#  ('аҥардастыы', 325),
#  ('өттө', 325),
#  ('нэһилиэк', 323),
#  ('көмүс', 322),
#  ('тыһыынча', 321),
#  ('сайдыытын', 321),
#  ('харыстыыр', 321),
#  ('холбуу', 319),
#  ('саҕана', 318),
#  ('сөптөөх', 317),
#  ('оҥорорун', 317),
#  ('сайдыыта', 317),
#  ('дьадаҥы', 317),
#  ('аҥы', 317),
#  ('баарын', 316),
#  ('быһыыларын', 316),
#  ('тутар', 315),
#  ('айылҕаҕа', 315),
#  ('оҥорорго', 315),
#  ('уһуннук', 314),
#  ('бэс', 313),
#  ('халлаан', 313),
#  ('сылтан', 312),
#  ('бэйэтигэр', 312),
#  ('уо', 311),
#  ('сыыйа', 311),
#  ('маҥнайгы', 310),
#  ('сайдар', 310),
#  ('сырдык', 310),
#  ('биирдэстэрэ', 308),
#  ('дириҥник', 308),
#  ('буолбакка', 306),
#  ('дьокуускай', 305),
#  ('нэһилиэнньэтин', 305),
#  ('асср', 304),
#  ('ийэтэ', 303),
#  ('ылбыт', 302),
#  ('кэлбит', 302),
#  ('таҥараларын', 302),
#  ('кэргэн', 301),
#  ('үһү', 301),
#  ('быһыылара', 300),
#  ('үлэлээн', 300),
#  ('уопсай', 299),
#  ('күүһэ', 299),
#  ('уустук', 298),
#  ('сылдьыбыта', 298),
#  ('туһата', 296),
#  ('дииллэр', 295),
#  ('о', 293),
#  ('өрөспүүбүлүкэтин', 292),
#  ('эдэрдэр', 292),
#  ('оннугар', 291),
#  ('бөдөҥ', 290),
#  ('кытаанах', 290),
#  ('таһаарар', 289),
#  ('саҕалаан', 289),
#  ('муора', 289),
#  ('оҥороро', 288),
#  ('сэриитин', 287),
#  ('буолбатах', 287),
#  ('дойдуну', 287),
#  ('суоҕа', 286),
#  ('ахсааннаах', 286),
#  ('үтүктэн', 285),
#  ('соҕотох', 285),
#  ('уһуна', 284),
#  ('буолбуттара', 284),
#  ('олохторугар', 284),
#  ('туһаналлар', 284),
#  ('туһанан', 282),
#  ('ситиһэр', 282),
#  ('түһэр', 282),
#  ('тылларын', 282),
#  ('хамнаһы', 282),
#  ('көтөр', 281),
#  ('күөх', 281),
#  ('түһэн', 281),
#  ('этиини', 281),
#  ('уран', 281),
#  ('чахчы', 280),
#  ('өйдөбүллээх', 279),
#  ('үөрэтиигэ', 278),
#  ('чугас', 278),
#  ('сиин', 278),
#  ('олохтоохторун', 277),
#  ('нэһилиэгэр', 277),
#  ('төрөппүт', 277),
#  ('айар', 276),
#  ('уон', 276),
#  ('үксүн', 276),
#  ('итини', 276),
#  ('туруктаах', 276),
#  ('үөрэхтээхтэрэ', 276),
#  ('үһүс', 275),
#  ('оҕотун', 275),
#  ('биллиилээх', 274),
#  ('кытары', 274),
#  ('иитиигэ', 274),
#  ('см', 273),
#  ('е', 272),
#  ('быһааран', 272),
#  ('туһанар', 271),
#  ('оскуолаҕа', 271),
#  ('тэрилтэ', 270),
#  ('сатыыллар', 270),
#  ('сэриигэ', 269),
#  ('айылҕаны', 269),
#  ('тыһ', 268),
#  ('бэйэлэригэр', 268),
#  ('аллараа', 268),
#  ('оҕоҕо', 268),
#  ('оҥорума', 268),
#  ('майгылаах', 268),
#  ('киирбитэ', 267),
#  ('ахш', 267),
#  ('көмөтүнэн', 267),
#  ('судаарыстыбаннай', 267),
#  ('хоһооно', 267),
#  ('биэс', 267),
#  ('төрүттээх', 266),
#  ('иван', 266),
#  ('оскуолатыгар', 265),
#  ('тымныы', 265),
#  ('быһыылар', 265),
#  ('олору', 265),
#  ('буолуохтаах', 264),
#  ('ахсааннара', 264),
#  ('тахсыбыта', 263),
#  ('сороҕор', 263),
#  ('тутуу', 263),
#  ('буоллахтарына', 263),
#  ('дьахталлар', 263),
#  ('кэриэтэ', 263),
#  ('сайын', 263),
#  ('сыһыаннаах', 262),
#  ('наука', 260),
#  ('нууччалар', 260),
#  ('иитии', 260),
#  ('научнай', 260),
#  ('ытык', 260),
#  ('биллэн', 260),
#  ('киирсэр', 259),
#  ('кыыл', 259),
#  ('национальнай', 259),
#  ('василий', 259),
#  ('тыллары', 258),
#  ('бастыҥ', 258),
#  ('киһиттэн', 258),
#  ('кэрэ', 258),
#  ('итэҕэл', 257),
#  ('дириҥ', 257),
#  ('бүтэрэн', 257),
#  ('санааларыгар', 256),
#  ('куһаҕаҥҥа', 256),
#  ('саҕаланар', 255),
#  ('быһыыта', 255),
#  ('барбыт', 255),
#  ('ааспыт', 255),
#  ('түүр', 255),
#  ('суруйааччы', 255),
#  ('кырдьык', 254),
#  ('ыраах', 252),
#  ('устар', 252),
#  ('суруйар', 252),
#  ('тиийэ', 252),
#  ('үүнэр', 252),
#  ('көҥүл', 251),
#  ('этэр', 251),
#  ('илдьэ', 251),
#  ('дойдутугар', 249),
#  ('кинигэ', 249),
#  ('сайдыытыгар', 249),
#  ('диир', 247),
#  ('дойдулар', 247),
#  ('нууччалыы', 247),
#  ('өһөс', 247),
#  ('бүтүн', 246),
#  ('киниэхэ', 246),
#  ('билиини', 245),
#  ('барбыта', 245),
#  ('ааҕыллар', 244),
#  ('сылгы', 244),
#  ('тыллара', 243),
#  ('көрүҥэ', 243),
#  ('дьокуускайга', 243),
#  ('ыйыгар', 242),
#  ('үөрэнэ', 242),
#  ('анал', 241),
#  ('этэн', 241),
#  ('түбэспэт', 241),
#  ('иһэрин', 239),
#  ('киhи', 238),
#  ('суолтата', 238),
#  ('элбэхтэр', 238),
#  ('олороллор', 237),
#  ('дойдуларга', 236),
#  ('үлэһитэ', 236),
#  ('оҥороллор', 236),
#  ('ууга', 236),
#  ('кинилэри', 235),
#  ('үлэтигэр', 235),
#  ('тутталлар', 234),
#  ('км²', 234),
#  ('биэрии', 234),
#  ('быдан', 234),
#  ('ыраас', 234),
#  ('ойуун', 234),
#  ('кырдьаҕас', 233),
#  ('сэрэхтээх', 233),
#  ('өҥнөөх', 232),
#  ('байыаннай', 231),
#  ('саас', 230),
#  ('суруйбут', 230),
#  ('эрэйиллэр', 230),
#  ('оччотооҕу', 230),
#  ('күүс', 230),
#  ('туһаныы', 229),
#  ('сааһыгар', 229),
#  ('үөрэхтээх', 229),
#  ('тута', 228),
#  ('эти', 227),
#  ('тарҕаммыт', 227),
#  ('ынах', 227),
#  ('дорҕоон', 227),
#  ('атырдьах', 226),
#  ('кииниттэн', 225),
#  ('сылдьара', 225),
#  ('сатааһын', 225),
#  ('ырыа', 224),
#  ('хараҥа', 224),
#  ('эрдэттэн', 223),
#  ('аатырбыт', 223),
#  ('куттара', 222),
#  ('бүтэрбитэ', 222),
#  ('истэн', 222),
#  ('атаах', 222),
#  ('тутулуга', 221),
#  ('саҥарар', 221),
#  ('өттүн', 221),
#  ('көмө', 221),
#  ('ууну', 221),
#  ('дьиэтэ', 220),
#  ('олохсуйбут', 220),
#  ('сэттэ', 219),
#  ('дии', 219),
#  ('таһыгар', 219),
#  ('суруйбута', 218),
#  ('лаппа', 218),
#  ('көтөн', 218),
#  ('буруйу', 218),
#  ('тылга', 218),
#  ('өйдөрүн', 218),
#  ('европа', 217),
#  ('тутуһар', 217),
#  ('баһылаан', 217),
#  ('өттүттэн', 217),
#  ('үөрэхтэрин', 217),
#  ('балаҕан', 216),
#  ('санаалар', 216),
#  ('ыҥырар', 215),
#  ('оруолу', 215),
#  ('уларыйар', 215),
#  ('тутаах', 214),
#  ('үйэтин', 214),
#  ('васильевич', 214),
#  ('үлэһиттэр', 213),
#  ('дьиҥнээх', 213),
#  ('оҥорууга', 213),
#  ('үйэлэргэ', 213),
#  ('быһыыга', 213),
#  ('сибиир', 212),
#  ('дьонугар', 212),
#  ('харчы', 211),
#  ('бэриллэр', 211),
#  ('үгэскэ', 211),
#  ('кыыллар', 211),
#  ('норуотун', 210),
#  ('кыратык', 210),
#  ('кыаҕын', 209),
#  ('оскуолатын', 208),
#  ('нэһилиэгин', 208),
#  ('буолуутун', 208),
#  ('иһинэн', 207),
#  ('эбиттэр', 206),
#  ('өйгө', 206),
#  ('ыраахтааҕы', 206),
#  ('ыар', 206),
#  ('быһаарыыны', 206),
#  ('таҥараны', 205),
#  ('кыахтара', 205),
#  ('ортотугар', 205),
#  ('өйдөөн', 205),
#  ('туруга', 205),
#  ('инники', 205),
#  ('сыыһаны', 205),
#  ('күнэ', 204),
#  ('кубулуйар', 204),
#  ('кэбиһэр', 204),
#  ('баайа', 203),
#  ('хаһаайыстыбатын', 202),
#  ('үгүстүк', 202),
#  ('көрө', 202),
#  ('николаевич', 202),
#  ('эрдэ', 201),
#  ('өйдөбүлү', 201),
#  ('тыынар', 200),
#  ('сөбүн', 200),
#  ('диэни', 200),
#  ('этиигэ', 200),
#  ('ыам', 199),
#  ('бүтэрбит', 198),
#  ('оҕолорго', 198),
#  ('саастаах', 198),
#  ('элбэҕи', 197),
#  ('үлэлэрин', 197),
#  ('кутугар', 197),
#  ('куората', 197),
#  ('бэлиэ', 197),
#  ('кэминэн', 197),
#  ('кэргэнэ', 197),
#  ('киллэрэн', 197),
#  ('петр', 196),
#  ('сайдыы', 196),
#  ('көрүү', 195),
#  ('үксүгэр', 195),
#  ('үйэлээх', 194),
#  ('аҕатын', 194),
#  ('үөрэҕэр', 194),
#  ('дьиэтин', 194),
#  ('дьонтон', 194),
#  ('харыстааһын', 194),
#  ('тула', 193),
#  ('охсон', 193),
#  ('көмөлөһөр', 192),
#  ('туһаны', 192),
#  ('буоланнар', 192),
#  ('аһыыр', 191),
#  ('оҥоһуллубут', 191),
#  ('республика', 191),
#  ('үөрэммитэ', 191),
#  ('барылара', 190),
#  ('барыларыгар', 190),
#  ('түүлгэ', 190),
#  ('оройуонун', 190),
#  ('бөлөх', 189),
#  ('дьайыыта', 189),
#  ('элбэхтэ', 188),
#  ('эрдэхтэринэ', 188),
#  ('өлбүтүн', 188),
#  ('саныыр', 188),
#  ('сылларыгар', 187),
#  ('нөҥүө', 187),
#  ('учуутал', 187),
#  ('суруллубут', 187),
#  ('буолбуттар', 187),
#  ('михаил', 186),
#  ('бигэргэтэр', 186),
#  ('билэ', 186),
#  ('табатык', 186),
#  ('үөрэнии', 186),
#  ('сс', 185),
#  ('оонньуу', 185),
#  ('этэринэн', 185),
#  ('сирдэрин', 185),
#  ('күүһүнэн', 185),
#  ('төрөппүттэрин', 185),
#  ('кэриҥэ', 184),
#  ('мэҥэ', 184),
#  ('иванович', 184),
#  ('оҕолоох', 184),
#  ('саба', 184),
#  ('чэпчэки', 183),
#  ('туһалааҕы', 183),
#  ('туттан', 183),
#  ('айылҕаттан', 182),
#  ('оҥорбута', 182),
#  ('ил', 181),
#  ('тэҥ', 181),
#  ('тэҥнээн', 181),
#  ('учуонай', 181),
#  ('бэлиэтэ', 181),
#  ('хамнас', 181),
#  ('тупсан', 181),
#  ('быһыылаахтык', 180),
#  ('түүл', 180),
#  ('мөлтөх', 180),
#  ('ситиһии', 180),
#  ('хаҥас', 180),
#  ('төгүл', 179),
#  ('кубулуйан', 179),
#  ('бааллара', 179),
#  ('алта', 179),
#  ('россияҕа', 179),
#  ('умнуллубат', 179),
#  ('тыллаах', 178),
#  ('тэҥҥэ', 177),
#  ('киллэрэр', 177),
#  ('ыарыыны', 177),
#  ('санаалары', 177),
#  ('дьарыктанар', 177),
#  ('көннөрү', 177),
#  ('оройуон', 177),
#  ('төттөрү', 177),
#  ('кулун', 176),
#  ('сыллар', 176),
#  ('буолбутун', 176),
#  ('оҥостон', 176),
#  ('иитэр', 176),
#  ('суруйааччыларын', 176),
#  ('буолуохтарын', 176),
#  ('этиллэр', 174),
#  ('дьиэтигэр', 174),
#  ('эрэн', 174),
#  ('иһэрэ', 174),
#  ('таһымыттан', 174),
#  ('өлбүтэ', 174),
#  ('америка', 173),
#  ('талан', 173),
#  ('дьокуускайдааҕы', 173),
#  ('бэлиэтэнэр', 173),
#  ('үөскэтэн', 173),
#  ('уҥа', 172),
#  ('этиилэрэ', 172),
#  ('мантан', 172),
#  ('кэмнэригэр', 172),
#  ('уратыта', 172),
#  ('сурукка', 171),
#  ('б', 171),
#  ('буолбат', 171),
#  ('уот', 171),
#  ('күүһүрэн', 171),
#  ('сиэр', 171),
#  ('ааһар', 170),
#  ('кыайа', 170),
#  ('оҕолоругар', 170),
#  ('уратыларын', 170),
#  ('сулус', 170),
#  ('бөҕө', 170),
#  ('тылбыт', 170),
#  ('ааттаналлар', 170),
#  ('хаҥалас', 169),
#  ('истэр', 169),
#  ('былааһы', 169),
#  ('православнай', 169),
#  ('түбэһэн', 169),
#  ('алдан', 169),
#  ('билимин', 169),
#  ('сылтаан', 168),
#  ('улууһугар', 168),
#  ('тутуһан', 168),
#  ('өрөспүүбүлүкэ', 168),
#  ('барытыгар', 167),
#  ('илии', 167),
#  ('күүһүн', 167),
#  ('быһаарыыга', 167),
#  ('сирдэрэ', 167),
#  ('уларыйбат', 167),
#  ('норуоттар', 166),
#  ('кыах', 166),
#  ('элбиир', 166),
#  ('этигэр', 166),
#  ('соччо', 166),
#  ('суруйааччылар', 166),
#  ('аттыгар', 166),
#  ('үгэстэри', 166),
#  ('тиийбэт', 165),
#  ('аньыы', 165),
#  ('чурапчы', 164),
#  ('арахсан', 164),
#  ('эргэ', 164),
#  ('тахсаллар', 164),
#  ('чуолкайдык', 163),
#  ('сыллаах', 163),
#  ('тан', 163),
#  ('иитэн', 163),
#  ('куһаҕана', 163),
#  ('олортон', 163),
#  ('эмискэ', 163),
#  ('арыы', 163),
#  ('көлүөнэ', 163),
#  ('киирэллэр', 162),
#  ('кэмин', 162),
#  ('дьоннор', 162),
#  ('сэргэ', 162),
#  ('алексей', 162),
#  ('сиини', 162),
#  ('үчүгэйгэ', 162),
#  ('туохха', 162),
#  ('кыһын', 162),
#  ('ай', 161),
#  ('э', 161),
#  ('уратылаах', 161),
#  ('сирдэригэр', 161),
#  ('салаатын', 160),
#  ('хам', 160),
#  ('ааттаммыт', 160),
#  ('аһаҕас', 160),
#  ('кыайыы', 160),
#  ('арыгыһыт', 160),
#  ('бочуоттаах', 159),
#  ...]

# %%
df = pd.DataFrame.from_dict(res)
df.columns = ["Word", "Count"]

# %%
df.head()
# Out:
#     Word  Count
# 0   диэн  16757
# 1  уонна  16435
# 2   киһи  13564
# 3     бу   9089
# 4     ол   7718

# %%
print("Full corpus length : " + str(len(df)))
# Out:
# Full corpus length : 116620

# %%
## Delete single letters

# %%
df = df[df['Word'].str.len() > 1]

# %%
df = df[df['Count'] >= 100]

# %%
df
# Out:
#             Word  Count
# 0           диэн  16757
# 1          уонна  16435
# 2           киһи  13564
# 3             бу   9089
# 4             ол   7718
# ...          ...    ...
# 1572    үчүгэйин    100
# 1573    иҥэринэн    100
# 1574      көрбүт    100
# 1575    үрдүктүк    100
# 1576  дакаастыыр    100
#
# [1559 rows x 2 columns]

# %%
df.to_csv("counter_sah_wiki.tsv", sep="\t", index=False)

# %%
df["Word"].to_csv("test_sah_wiki.tsv", index=False, header=False)

# %%
## cat test_sah_wiki.tsv | flookup sah_full.bin > sah_corpus_results.txt
