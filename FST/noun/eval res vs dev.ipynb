# %%
import pandas as pd
#import numpy as np

# %%
colnames= ["LEMMA", "WORD_RES"]
df_res = pd.read_csv("sah_noun_results.txt", sep="\t", encoding="utf-8", names=colnames, header=None)
df_res#.head()

df_res["LEMMA"]
# Out:
# 0                                   бу<DET>
# 1                                 аайы<DET>
# 2                         бу<DET><Case=Acc>
# 3       яблоко<NOUN><Number=Sing><Case=Abl>
# 4      оскуола<NOUN><Number=Sing><Case=Abl>
#                        ...
# 372                 петров<PROPN><Case=Dat>
# 373             дьокуускай<PROPN><Case=Dat>
# 374                  айхал<PROPN><Case=Dat>
# 375                 кэскил<PROPN><Case=Dat>
# 376                  айтал<PROPN><Case=Dat>
# Name: LEMMA, Length: 377, dtype: object

# %%
colnames2= ["LEMMA", "WORD_COR", "POS"]
df_dev = pd.read_csv("./eval_noun/sah_noun.dev", sep="\t", encoding="utf-8", names=colnames2)
df_dev["POS"] = df_dev["POS"].str.replace(r"|","")
df_dev["POS"]
# Out:
# /var/folders/2p/6pqnd6yj0zx2p_7m_3ntmldm0000gn/T/ipykernel_1886/521077834.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_dev["POS"] = df_dev["POS"].str.replace(r"|","")
# 0                              <DET>
# 1                              <DET>
# 2                    <DET><Case=Acc>
# 3      <NOUN><Number=Sing><Case=Abl>
# 4      <NOUN><Number=Sing><Case=Abl>
#                    ...
# 372                <PROPN><Case=Dat>
# 373                <PROPN><Case=Dat>
# 374                <PROPN><Case=Dat>
# 375                <PROPN><Case=Dat>
# 376                <PROPN><Case=Dat>
# Name: POS, Length: 377, dtype: object

# %%
df_dev["LEMMA"] = df_dev["LEMMA"] + df_dev["POS"]
newlist = df_res["LEMMA"].tolist()

# %%
df_dev = df_dev.drop("POS", axis=1)
df_dev
# Out:
#                                     LEMMA      WORD_COR
# 0                                 бу<DET>            бу
# 1                               аайы<DET>          аайы
# 2                       бу<DET><Case=Acc>          маны
# 3     яблоко<NOUN><Number=Sing><Case=Abl>    яблокаттан
# 4    оскуола<NOUN><Number=Sing><Case=Abl>   оскуолаттан
# ..                                    ...           ...
# 372               петров<PROPN><Case=Dat>      петровка
# 373           дьокуускай<PROPN><Case=Dat>  дьокуускайга
# 374                айхал<PROPN><Case=Dat>       айхалга
# 375               кэскил<PROPN><Case=Dat>      кэскилга
# 376                айтал<PROPN><Case=Dat>       айталга
#
# [377 rows x 2 columns]

# %%
df_all = pd.concat([df_dev, df_res], axis=1)
df_all["LEMMA"] = df_all["LEMMA"] + df_all["LEMMA"]
df_all = df_all.drop("LEMMA", axis=1)
df_all
# Out:
#          WORD_COR      WORD_RES
# 0              бу            бу
# 1            аайы          аайы
# 2            маны          маны
# 3      яблокаттан    яблокаттан
# 4     оскуолаттан   оскуолаттан
# ..            ...           ...
# 372      петровка      петровка
# 373  дьокуускайга  дьокуускайга
# 374       айхалга       айхалга
# 375      кэскилга      кэскилга
# 376       айталга       айталга
#
# [377 rows x 2 columns]

# %%
def hl(d):
    df = pd.DataFrame(columns=d.columns, index=d.index)
    #df.loc[d['WORD_RES'].ne(d['WORD_COR'])] = 'background: yellow'
    df.loc[d['WORD_RES'].ne(d['WORD_COR']), ['WORD_RES', 'WORD_COR']] = 'background: red'
    return df

# %%
result = df_all.style.apply(hl, axis=None)
result
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2f1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2f1f_level0_col0" class="col_heading level0 col0" >WORD_COR</th>
#       <th id="T_d2f1f_level0_col1" class="col_heading level0 col1" >WORD_RES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2f1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2f1f_row0_col0" class="data row0 col0" >бу</td>
#       <td id="T_d2f1f_row0_col1" class="data row0 col1" >бу</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2f1f_row1_col0" class="data row1 col0" >аайы</td>
#       <td id="T_d2f1f_row1_col1" class="data row1 col1" >аайы</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2f1f_row2_col0" class="data row2 col0" >маны</td>
#       <td id="T_d2f1f_row2_col1" class="data row2 col1" >маны</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2f1f_row3_col0" class="data row3 col0" >яблокаттан</td>
#       <td id="T_d2f1f_row3_col1" class="data row3 col1" >яблокаттан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2f1f_row4_col0" class="data row4 col0" >оскуолаттан</td>
#       <td id="T_d2f1f_row4_col1" class="data row4 col1" >оскуолаттан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2f1f_row5_col0" class="data row5 col0" >ынахтан</td>
#       <td id="T_d2f1f_row5_col1" class="data row5 col1" >ынахтан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2f1f_row6_col0" class="data row6 col0" >ыстаалтан</td>
#       <td id="T_d2f1f_row6_col1" class="data row6 col1" >ыстаалтан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2f1f_row7_col0" class="data row7 col0" >халлаантан</td>
#       <td id="T_d2f1f_row7_col1" class="data row7 col1" >халлаантан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2f1f_row8_col0" class="data row8 col0" >баһаартан</td>
#       <td id="T_d2f1f_row8_col1" class="data row8 col1" >баһаартан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2f1f_row9_col0" class="data row9 col0" >буочукаттан</td>
#       <td id="T_d2f1f_row9_col1" class="data row9 col1" >буочукаттан</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d2f1f_row10_col0" class="data row10 col0" >үөннэри</td>
#       <td id="T_d2f1f_row10_col1" class="data row10 col1" >үөннэри</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d2f1f_row11_col0" class="data row11 col0" >көтөрдөрү</td>
#       <td id="T_d2f1f_row11_col1" class="data row11 col1" >көтөрдөрү</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d2f1f_row12_col0" class="data row12 col0" >кинигэлэри</td>
#       <td id="T_d2f1f_row12_col1" class="data row12 col1" >кинигэлэри</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d2f1f_row13_col0" class="data row13 col0" >километры</td>
#       <td id="T_d2f1f_row13_col1" class="data row13 col1" >километры</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d2f1f_row14_col0" class="data row14 col0" >ааннары</td>
#       <td id="T_d2f1f_row14_col1" class="data row14 col1" >ааннары</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d2f1f_row15_col0" class="data row15 col0" >оҕолору</td>
#       <td id="T_d2f1f_row15_col1" class="data row15 col1" >оҕолору</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d2f1f_row16_col0" class="data row16 col0" >ыскааптары</td>
#       <td id="T_d2f1f_row16_col1" class="data row16 col1" >ыскааптары</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d2f1f_row17_col0" class="data row17 col0" >харандааһы</td>
#       <td id="T_d2f1f_row17_col1" class="data row17 col1" >харандааһы</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d2f1f_row18_col0" class="data row18 col0" >этэрбэһи</td>
#       <td id="T_d2f1f_row18_col1" class="data row18 col1" >этэрбэһи</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d2f1f_row19_col0" class="data row19 col0" >карточканы</td>
#       <td id="T_d2f1f_row19_col1" class="data row19 col1" >карточканы</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d2f1f_row20_col0" class="data row20 col0" >түннүгү</td>
#       <td id="T_d2f1f_row20_col1" class="data row20 col1" >түннүгү</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d2f1f_row21_col0" class="data row21 col0" >дьону</td>
#       <td id="T_d2f1f_row21_col1" class="data row21 col1" >дьону</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d2f1f_row22_col0" class="data row22 col0" >килиэби</td>
#       <td id="T_d2f1f_row22_col1" class="data row22 col1" >килиэби</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d2f1f_row23_col0" class="data row23 col0" >суругу</td>
#       <td id="T_d2f1f_row23_col1" class="data row23 col1" >суругу</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d2f1f_row24_col0" class="data row24 col0" >чулкуну</td>
#       <td id="T_d2f1f_row24_col1" class="data row24 col1" >чулкуну</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d2f1f_row25_col0" class="data row25 col0" >киһини</td>
#       <td id="T_d2f1f_row25_col1" class="data row25 col1" >киһини</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d2f1f_row26_col0" class="data row26 col0" >эһэни</td>
#       <td id="T_d2f1f_row26_col1" class="data row26 col1" >эһэни</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d2f1f_row27_col0" class="data row27 col0" >сыаны</td>
#       <td id="T_d2f1f_row27_col1" class="data row27 col1" >сыаны</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d2f1f_row28_col0" class="data row28 col0" >оту</td>
#       <td id="T_d2f1f_row28_col1" class="data row28 col1" >оту</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d2f1f_row29_col0" class="data row29 col0" >тэтэрээти</td>
#       <td id="T_d2f1f_row29_col1" class="data row29 col1" >тэтэрээти</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d2f1f_row30_col0" class="data row30 col0" >хамнаһы</td>
#       <td id="T_d2f1f_row30_col1" class="data row30 col1" >хамнаһы</td>
#     </tr>
#     <tr>
#       <th id="T_d2f1f_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_d2f1f_row31_col0" class="data row31 col0" >бөрөнү</td>
#       <td id="T_d2f1f_row31_col1" class="data row31 col1" >бөрөнү</td>
#     </tr>
#     <tr>
#       <th i

# %%
result.to_html('differenceEvalDev.html')
