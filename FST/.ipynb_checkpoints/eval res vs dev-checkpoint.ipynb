# %%
import pandas as pd

# %%
colnames= ["LEMMA", "WORD_RES"]
df_res = pd.read_csv("sah_full_results.txt", sep="\t", encoding="utf-8", names=colnames, header=None)
df_res#.head()

df_res["LEMMA"]
# Out:
# 0                                            бу<DET>
# 1                                          аайы<DET>
# 2                                  бу<DET><Case=Acc>
# 3                яблоко<NOUN><Number=Sing><Case=Abl>
# 4                ыстаал<NOUN><Number=Sing><Case=Abl>
#                            ...
# 664    ыҥыр<VERB><Number=Sing><Person=3><Tense=Pres>
# 665     гын<VERB><Number=Sing><Person=3><Tense=Pres>
# 666     уст<VERB><Number=Sing><Person=3><Tense=Pres>
# 667            күл<VERB><Tense=Pres><VerbForm=Trans>
# 668            үүн<VERB><Tense=Pres><VerbForm=Trans>
# Name: LEMMA, Length: 669, dtype: object

# %%
colnames2= ["LEMMA", "WORD_COR", "POS"]
df_dev = pd.read_csv("/Users/tatiana/Documents/Uni/Thesis/FST/FST/full/eval/sah_full.dev", sep="\t", encoding="utf-8", names=colnames2)
df_dev["POS"] = df_dev["POS"].str.replace(r"|","")
df_dev["POS"]
# Out:
# <ipython-input-12-ee9bc9e28969>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_dev["POS"] = df_dev["POS"].str.replace(r"|","")
# 0                                          <DET>
# 1                                          <DET>
# 2                                <DET><Case=Acc>
# 3                  <NOUN><Number=Sing><Case=Abl>
# 4                  <NOUN><Number=Sing><Case=Abl>
#                          ...
# 664    <VERB><Number=Sing><Person=3><Tense=Pres>
# 665    <VERB><Number=Sing><Person=3><Tense=Pres>
# 666    <VERB><Number=Sing><Person=3><Tense=Pres>
# 667           <VERB><Tense=Pres><VerbForm=Trans>
# 668           <VERB><Tense=Pres><VerbForm=Trans>
# Name: POS, Length: 669, dtype: object

# %%
df_dev["LEMMA"] = df_dev["LEMMA"] + df_dev["POS"]
newlist = df_res["LEMMA"].tolist()

# %%
df_dev = df_dev.drop("POS", axis=1)
df_dev
# Out:
#                                              LEMMA    WORD_COR
# 0                                          бу<DET>          бу
# 1                                        аайы<DET>        аайы
# 2                                бу<DET><Case=Acc>        маны
# 3              яблоко<NOUN><Number=Sing><Case=Abl>  яблокаттан
# 4              ыстаал<NOUN><Number=Sing><Case=Abl>   ыстаалтан
# ..                                             ...         ...
# 664  ыҥыр<VERB><Number=Sing><Person=3><Tense=Pres>      ыҥырар
# 665   гын<VERB><Number=Sing><Person=3><Tense=Pres>       гынар
# 666   уст<VERB><Number=Sing><Person=3><Tense=Pres>       устар
# 667          күл<VERB><Tense=Pres><VerbForm=Trans>        күлэ
# 668          үүн<VERB><Tense=Pres><VerbForm=Trans>        үүнэ
#
# [669 rows x 2 columns]

# %%
df_all = pd.concat([df_dev, df_res], axis=1)
df_all["LEMMA"] = df_all["LEMMA"] + df_all["LEMMA"]
df_all = df_all.drop("LEMMA", axis=1)
df_all
# Out:
#        WORD_COR    WORD_RES
# 0            бу          бу
# 1          аайы        аайы
# 2          маны        маны
# 3    яблокаттан  яблокаттан
# 4     ыстаалтан   ыстаалтан
# ..          ...         ...
# 664      ыҥырар      ыҥырар
# 665       гынар       гынар
# 666       устар       устар
# 667        күлэ        күлэ
# 668        үүнэ        үүнэ
#
# [669 rows x 2 columns]

# %%
def hl(d):
    df = pd.DataFrame(columns=d.columns, index=d.index)
    #df.loc[d['WORD_RES'].ne(d['WORD_COR'])] = 'background: yellow'
    df.loc[d['WORD_RES'].ne(d['WORD_COR']), ['WORD_RES', 'WORD_COR']] = 'background: red'
    return df

# %%
result = df_all.style.apply(hl, axis=None)
result
# Out:
# <style type="text/css">
# </style>
# <table id="T_85924">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85924_level0_col0" class="col_heading level0 col0" >WORD_COR</th>
#       <th id="T_85924_level0_col1" class="col_heading level0 col1" >WORD_RES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85924_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85924_row0_col0" class="data row0 col0" >бу</td>
#       <td id="T_85924_row0_col1" class="data row0 col1" >бу</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85924_row1_col0" class="data row1 col0" >аайы</td>
#       <td id="T_85924_row1_col1" class="data row1 col1" >аайы</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85924_row2_col0" class="data row2 col0" >маны</td>
#       <td id="T_85924_row2_col1" class="data row2 col1" >маны</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85924_row3_col0" class="data row3 col0" >яблокаттан</td>
#       <td id="T_85924_row3_col1" class="data row3 col1" >яблокаттан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85924_row4_col0" class="data row4 col0" >ыстаалтан</td>
#       <td id="T_85924_row4_col1" class="data row4 col1" >ыстаалтан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85924_row5_col0" class="data row5 col0" >баһаартан</td>
#       <td id="T_85924_row5_col1" class="data row5 col1" >баһаартан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85924_row6_col0" class="data row6 col0" >буочукаттан</td>
#       <td id="T_85924_row6_col1" class="data row6 col1" >буочукаттан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85924_row7_col0" class="data row7 col0" >ынахтан</td>
#       <td id="T_85924_row7_col1" class="data row7 col1" >ынахтан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85924_row8_col0" class="data row8 col0" >халлаантан</td>
#       <td id="T_85924_row8_col1" class="data row8 col1" >халлаантан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_85924_row9_col0" class="data row9 col0" >оскуолаттан</td>
#       <td id="T_85924_row9_col1" class="data row9 col1" >оскуолаттан</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_85924_row10_col0" class="data row10 col0" >оҕолору</td>
#       <td id="T_85924_row10_col1" class="data row10 col1" >оҕолору</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_85924_row11_col0" class="data row11 col0" >ааннары</td>
#       <td id="T_85924_row11_col1" class="data row11 col1" >ааннары</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_85924_row12_col0" class="data row12 col0" >ыскааптары</td>
#       <td id="T_85924_row12_col1" class="data row12 col1" >ыскааптары</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_85924_row13_col0" class="data row13 col0" >километры</td>
#       <td id="T_85924_row13_col1" class="data row13 col1" >километры</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_85924_row14_col0" class="data row14 col0" >көтөрдөрү</td>
#       <td id="T_85924_row14_col1" class="data row14 col1" >көтөрдөрү</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_85924_row15_col0" class="data row15 col0" >кинигэлэри</td>
#       <td id="T_85924_row15_col1" class="data row15 col1" >кинигэлэри</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_85924_row16_col0" class="data row16 col0" >үөннэри</td>
#       <td id="T_85924_row16_col1" class="data row16 col1" >үөннэри</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_85924_row17_col0" class="data row17 col0" >түннүгү</td>
#       <td id="T_85924_row17_col1" class="data row17 col1" >түннүгү</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_85924_row18_col0" class="data row18 col0" >форточканы</td>
#       <td id="T_85924_row18_col1" class="data row18 col1" >форточканы</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_85924_row19_col0" class="data row19 col0" >бэргэһэни</td>
#       <td id="T_85924_row19_col1" class="data row19 col1" >бэргэһэни</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_85924_row20_col0" class="data row20 col0" >ууну</td>
#       <td id="T_85924_row20_col1" class="data row20 col1" >ууну</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_85924_row21_col0" class="data row21 col0" >ааны</td>
#       <td id="T_85924_row21_col1" class="data row21 col1" >ааны</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_85924_row22_col0" class="data row22 col0" >килиэби</td>
#       <td id="T_85924_row22_col1" class="data row22 col1" >килиэби</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_85924_row23_col0" class="data row23 col0" >наскыны</td>
#       <td id="T_85924_row23_col1" class="data row23 col1" >наскыны</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_85924_row24_col0" class="data row24 col0" >этэрбэһи</td>
#       <td id="T_85924_row24_col1" class="data row24 col1" >этэрбэһи</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_85924_row25_col0" class="data row25 col0" >харандааһы</td>
#       <td id="T_85924_row25_col1" class="data row25 col1" >харандааһы</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_85924_row26_col0" class="data row26 col0" >тэтэрээти</td>
#       <td id="T_85924_row26_col1" class="data row26 col1" >тэтэрээти</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_85924_row27_col0" class="data row27 col0" >кинигэни</td>
#       <td id="T_85924_row27_col1" class="data row27 col1" >кинигэни</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_85924_row28_col0" class="data row28 col0" >иһити</td>
#       <td id="T_85924_row28_col1" class="data row28 col1" >иһити</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_85924_row29_col0" class="data row29 col0" >таҥаһы</td>
#       <td id="T_85924_row29_col1" class="data row29 col1" >таҥаһы</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_85924_row30_col0" class="data row30 col0" >оҕону</td>
#       <td id="T_85924_row30_col1" class="data row30 col1" >оҕону</td>
#     </tr>
#     <tr>
#       <th id="T_85924_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_85924_row31_col0" class="data row31 col0" >күлгэрини</td>
#       <td id="T_85924_row31_col1" class="data row31 col1" >күлгэрини</td>
#     </tr>
#     <t

# %%
result.to_html('differenceEvalDev.html')
